# %%
print("Hello world!")
# Out:
# Running cells with '.ml (3.14.6.final.0) (Python 3.14.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/sagarchhikara/Personal-code-practice/.ml/bin/python -m pip install ipykernel -U --force-reinstall'
