# %%
print("hello world", end=" ")
print("My name is sagar chhikara")
print(10)
print(20*10)
print("I am",20,"year old")
# Out:
# hello world My name is sagar chhikara
# 10
# 200
# I am 20 year old

# %%
# VAriables in python
# variable names are case sensitive
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)
# A variable name cannot be any of the Python keywords.

x=5
y="sagar"
print(x)
print(y)
# Out:
# 5
# sagar

# %%
# Global variables
#Variables that are created outside of a function (as in all of the examples in the previous pages) are known as global variables Global variables can be used by everyone, both inside of functions and outside.
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()
def myfunc1():
  x = "fantastic"
  print("Python is " + x)
myfunc1()
print("Python is " + x)
def myfunc2():
  global y
  y = "lassan"

myfunc2()

print("Python is " + y)
# Out:
# Python is awesome
# Python is fantastic
# Python is awesome
# Python is lassan

# %%
# WHile loop
i = 1
while i < 6:
  print(i)
  i += 1
  # Continue break and else conditon
j=0
while j< 6:
  j += 1
  if j == 3:
    continue
  print(j)
# Out:
# 1
# 2
# 3
# 4
# 5
# 1
# 2
# 4
# 5
# 6
